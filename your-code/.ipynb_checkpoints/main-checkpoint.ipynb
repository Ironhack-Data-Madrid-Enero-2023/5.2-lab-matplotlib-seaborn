# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import pylab as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('../data/Fitbit2.csv')

fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED

fitbit[['Steps', 'Months_encoded']].describe().T
# Out:
#                 count          mean          std  min     25%      50%  \
# Steps           367.0  10121.588556  5594.836225  0.0  6730.5  10413.0
# Months_encoded  367.0      6.501362     3.459267  1.0     3.5      7.0
#
#                     75%      max
# Steps           13916.5  26444.0
# Months_encoded      9.5     12.0

# %%
fitbit[['Steps', 'Months_encoded']].groupby('Months_encoded').median().plot(kind='bar');

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
fitbit[['Steps', 'Work_or_Weekend']].groupby('Work_or_Weekend').median().plot(kind='bar');

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
tuplas = [("Minutes Lightly Active", "Poco activo"), 
          ("Minutes Very Active", "Muy activo"), 
          ("Minutes Sedentary", "Sedentario")]

for tupla, label in tuplas:
    plt.scatter(fitbit["Steps"], fitbit[tupla], label=label)

plt.legend()
plt.xlabel("Steps")
plt.ylabel("Minutes")

plt.show();

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('../data/titanic.csv')

titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.dtypes == 'int64'
# Out:
# PassengerId     True
# Survived       False
# Pclass          True
# Name           False
# Gender         False
# Age            False
# SibSp           True
# Parch           True
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
titanic.dtypes == 'float64'
# Out:
# PassengerId    False
# Survived        True
# Pclass         False
# Name           False
# Gender         False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
# CATEGORICAL VARIABLES
titanic.dtypes == object
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Gender          True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.hist(titanic.Age, bins=40);

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 6))
axs[0].hist(titanic["Age"], bins=10)
axs[1].hist(titanic["Age"], bins=20)
axs[2].hist(titanic["Age"], bins=50)
plt.show();

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
A mayor número de barras más se aprecian los valores únicos, vemos vacíos, etc.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(titanic.Age, bins=40);

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.hist(titanic.Gender, bins=2);

# %%
# Method 2 - seaborn
sns.histplot(titanic.Gender, bins=2);

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
titanic.Pclass.value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
titanic.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
plt.bar(titanic.Pclass.unique(), [titanic.Pclass.value_counts()[3],
                         titanic.Pclass.value_counts()[1],
                         titanic.Pclass.value_counts()[2]]);

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
titanic.Age.plot.box(grid=True);

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Así puedo ver donde están la mayoría de datos(entre 20 y 40 años), la mediana(~=29), q1 y q3, 
los outliers, etc.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
titanic.Age.hist()
plt.axvline(titanic.Age.median(), color='red', linewidth=2)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Aquí también puedo ver que la mayoría de datos están entre 20 y 40 y que la mediana está cerca de 29 años.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
corr = titanic.corr()['Fare']
corr = corr.iloc[3:6:3]
corr
# Out:
# C:\Users\elmat\AppData\Local\Temp\ipykernel_14564\2595590888.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = titanic.corr()['Fare']
# Age    0.171355
# Name: Fare, dtype: float64

# %%
plt.plot(titanic.Fare, titanic.Age, 'o');

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
