# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import warnings
warnings.simplefilter('ignore')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

import pandas as pd
import numpy as np

import pylab as plt
import seaborn as sns

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

fitbit = pd.read_csv('../data/Fitbit2.csv')

fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
# your code here

data = fitbit[['Months_encoded', 'Steps']].groupby('Months_encoded').mean()

data.plot.bar(figsize=(12, 4));

plt.savefig('../figures/figure1.png')

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here
data = fitbit[['Work_or_Weekend', 'Steps']].groupby('Work_or_Weekend').mean()

data.plot.bar(figsize=(12, 4));

plt.savefig('../figures/figure2.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
column = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

for e in column:
    plt.scatter(fitbit[e], fitbit['Steps'])
    plt.xlabel(e)
    plt.ylabel('Steps')
    plt.savefig(e + '.png')
    plt.show();

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 6))    # pinta 1 fila 3 columnas, 3 plots en fila

for i,cat in enumerate(fitbit.index[:3]):
    sns.scatterplot(data=fitbit, x='Minutes Lightly Active', y='Steps', ax=ax[0])
    sns.scatterplot(data=fitbit, x='Minutes Fairly Active', y='Steps', ax=ax[1])
    sns.scatterplot(data=fitbit, x='Minutes Very Active', y='Steps', ax=ax[2])

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

titanic = sns.load_dataset('titanic')

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

titanic.select_dtypes(include=['int', 'float', 'object'])
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked    who  \
# 0           0       3    male  22.00      1      0    7.2500        S    man
# 1           1       1  female  38.00      1      0   71.2833        C  woman
# 2           1       3  female  26.00      0      0    7.9250        S  woman
# 3           1       1  female  35.00      1      0   53.1000        S  woman
# 4           0       3    male  35.00      0      0    8.0500        S    man
# 5           0       3    male    NaN      0      0    8.4583        Q    man
# 6           0       1    male  54.00      0      0   51.8625        S    man
# 7           0       3    male   2.00      3      1   21.0750        S  child
# 8           1       3  female  27.00      0      2   11.1333        S  woman
# 9           1       2  female  14.00      1      0   30.0708        C  child
# 10          1       3  female   4.00      1      1   16.7000        S  child
# ...

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include=['int', 'float'])
# Out:
#      survived  pclass    age  sibsp  parch      fare
# 0           0       3  22.00      1      0    7.2500
# 1           1       1  38.00      1      0   71.2833
# 2           1       3  26.00      0      0    7.9250
# 3           1       1  35.00      1      0   53.1000
# 4           0       3  35.00      0      0    8.0500
# 5           0       3    NaN      0      0    8.4583
# 6           0       1  54.00      0      0   51.8625
# 7           0       3   2.00      3      1   21.0750
# 8           1       3  27.00      0      2   11.1333
# 9           1       2  14.00      1      0   30.0708
# 10          1       3   4.00      1      1   16.7000
# 11          1       1  58.00      0      0   26.5500
# 12          0       3  20.00      0      0    8.0500
# 13          0       3  39.00      1      5   31.2750
# 14          0       3  14.00      0      0    7.8542
# 15          1       2  55.00      0      0   16.0000
# 16          0       3   2.00      4      1   29.1250
# ...

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(exclude=['int', 'float'])
# Out:
#         sex embarked   class    who  adult_male deck  embark_town alive  alone
# 0      male        S   Third    man        True  NaN  Southampton    no  False
# 1    female        C   First  woman       False    C    Cherbourg   yes  False
# 2    female        S   Third  woman       False  NaN  Southampton   yes   True
# 3    female        S   First  woman       False    C  Southampton   yes  False
# 4      male        S   Third    man        True  NaN  Southampton    no   True
# 5      male        Q   Third    man        True  NaN   Queenstown    no   True
# 6      male        S   First    man        True    E  Southampton    no   True
# 7      male        S   Third  child       False  NaN  Southampton    no  False
# 8    female        S   Third  woman       False  NaN  Southampton   yes  False
# 9    female        C  Second  child       False  NaN    Cherbourg   yes  False
# 10   female        S   Third  child       False    G  Southampton   yes  False
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

plt.style.use('classic')
fig, ax = plt.subplots(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

sns.histplot(x=titanic.age)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
sns.histplot(x=titanic.age, bins=10)
sns.histplot(x=titanic.age, bins=20)
sns.histplot(x=titanic.age, bins=50)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
plt.hist(titanic.age, bins=10)
plt.hist(titanic.age, bins=20)
plt.hist(titanic.age, bins=50);

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Al tratarse de un count por defecto, a mayor es el tamaño del bin, más datos acumulados habrá y por lo tanto 
barras serán más grandes
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.histplot(x=titanic.age);

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.hist(titanic.sex, bins=2);

# %%
# Method 2 - seaborn
# your code here
sns.histplot(x=titanic.sex);

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
titanic.head(1)

titanic[['class']].groupby('class').value_counts().plot.bar()
# Out:
# <AxesSubplot:xlabel='class'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

titanic[['age']].boxplot();

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
La mediana se situa en 29 años, a partir de +- 63 años, son considerados outliers. La mitad de pasajeros tienen entre 
20 y 40 años
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
titanic[['age']].boxplot()
plt.hist(titanic.age, bins=50);

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
La misma que llevamos viendo durante todo el ejercicio
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
# Method 1 - matplotlib
# your code here

plt.scatter(x = titanic.fare, y = titanic.age)

# %%
# Method 2 - seaborn
# your code here

corr = titanic[['fare', 'age']].corr()

sns.set(style='white')                            # estilo blanco

mascara=np.triu(np.ones_like(corr, dtype=bool))   # genera una mascara

cmap=sns.diverging_palette(0, 10, as_cmap=True)   # paleta de colores


sns.heatmap(corr,             # datos
            mask=mascara,     # mascara
            cmap=cmap,        # color
            vmax=1,           # maximo vertical
            vmin=-1,          # minimo vertical
            center=0,         # centro
            square=True,      # cuadrado el dato pintado
            linewidth=0.5,    # ancho de la linea
            
            cbar_kws={'shrink': 0.5},  # barra de color
            annot=True                 # anotacion, el numero escrito
           );

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr=titanic.corr(method='pearson')

# %%
# your code here

sns.set(style='white')                            # estilo blanco

mascara=np.triu(np.ones_like(corr, dtype=bool))   # genera una mascara

cmap=sns.diverging_palette(0, 10, as_cmap=True)   # paleta de colores


sns.heatmap(corr,             # datos
            mask=mascara,     # mascara
            cmap=cmap,        # color
            vmax=1,           # maximo vertical
            vmin=-1,          # minimo vertical
            center=0,         # centro
            square=True,      # cuadrado el dato pintado
            linewidth=0.5,    # ancho de la linea
            
            cbar_kws={'shrink': 0.5},  # barra de color
            annot=True                 # anotacion, el numero escrito
           );

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

sns.boxplot(x='class', y='age', data=titanic);

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
g = sns.FacetGrid(titanic, col='sex')
g.map(plt.hist, 'age', bins=20)
plt.show()
