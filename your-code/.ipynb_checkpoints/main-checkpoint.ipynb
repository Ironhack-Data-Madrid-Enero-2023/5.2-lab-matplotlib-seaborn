# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import pandas as pd
import numpy as np
import pylab as plt
import seaborn as sns

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv(r"C:\Users\manue\OneDrive\Escritorio\Ironhack\semana_5\5.2-lab-matplotlib-seaborn\data\Fitbit2.csv")

# %%
fitbit.head(5)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
mediansteps = fitbit.groupby('Months_encoded')['Steps'].median()
mediansteps.reset_index()
#AVERAGE STEPS BY MONTH_ENCODED

# your code here
# Out:
#     Months_encoded    Steps
# 0                1  10366.0
# 1                2   9235.0
# 2                3  11122.0
# 3                4  13846.5
# 4                5  11998.0
# 5                6  12935.5
# 6                7  10644.0
# 7                8  12213.0
# 8                9   9343.0
# 9               10   7865.0
# 10              11   9453.5
# 11              12   8531.0

# %%
mediansteps = mediansteps.reset_index()

# %%
plt.bar(x= mediansteps.Months_encoded, height = mediansteps.Steps)
plt.rcParams['figure.figsize']=(12, 4)
plt.sca
plt.xticks(ticks=mediansteps.Months_encoded);

# %%
median_steps = fitbit.groupby('Work_or_Weekend')['Steps'].median()
median_steps = median_steps.reset_index()
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here

# %%
plt.bar(x = median_steps.Work_or_Weekend, height = median_steps.Steps)
plt.rcParams['figure.figsize']=(12, 4)
plt.sca
plt.xticks(ticks=median_steps.Work_or_Weekend);

# %%
median_steps.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fitbit.head(5)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %%
   # pinta 1 fila 3 columnas, 3 plots en fila
columns = ['Minutes Lightly Active', 'Minutes Fairly Active', 'Minutes Very Active']

for x in columns:
    plt.scatter(fitbit['Steps'], fitbit[x])
    plt.xlabel('Steps')
    plt.ylabel(x)
    plt.title(f'Steps vs {x}')
    plt.show()

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv(r"C:\Users\manue\OneDrive\Escritorio\Ironhack\semana_5\5.2-lab-matplotlib-seaborn\data\titanic.csv")
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
titanic.describe().T
# Out:
#               count        mean         std   min       25%       50%  \
# PassengerId  1309.0  655.000000  378.020061  1.00  328.0000  655.0000
# Survived      891.0    0.383838    0.486592  0.00    0.0000    0.0000
# Pclass       1309.0    2.294882    0.837836  1.00    2.0000    3.0000
# Age          1309.0   29.879186   13.448335  0.17   22.0000   28.5000
# SibSp        1309.0    0.498854    1.041658  0.00    0.0000    0.0000
# Parch        1309.0    0.385027    0.865560  0.00    0.0000    0.0000
# Fare         1309.0   33.281086   51.741500  0.00    7.8958   14.4542
#
#                  75%        max
# PassengerId  982.000  1309.0000
# Survived       1.000     1.0000
# Pclass         3.000     3.0000
# Age           37.000    80.0000
# SibSp          1.000     8.0000
# Parch          0.000     9.0000
# Fare          31.275   512.3292

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
numerical = titanic.select_dtypes(include=np.number)
numerical
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
categorical = titanic.select_dtypes(include=object)
categorical
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.figure(figsize=(12,6));

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic.Age
# Out:
# 0       22.000000
# 1       38.000000
# 2       26.000000
# 3       35.000000
# 4       35.000000
#           ...
# 1304    29.513190
# 1305    39.000000
# 1306    38.500000
# 1307    29.513190
# 1308    25.315435
# Name: Age, Length: 1309, dtype: float64

# %%
numerical.Age
# Out:
# 0       22.000000
# 1       38.000000
# 2       26.000000
# 3       35.000000
# 4       35.000000
#           ...
# 1304    29.513190
# 1305    39.000000
# 1306    38.500000
# 1307    29.513190
# 1308    25.315435
# Name: Age, Length: 1309, dtype: float64

# %%
plt.hist(numerical['Age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Age');

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, ax = plt.subplots(1, 3, sharey=True)
numerical.Age.plot.hist(bins=10, ax=ax[0]);

numerical.Age.plot.hist(bins=20, ax=ax[1]);

numerical.Age.plot.hist(bins=50, ax=ax[2]);


fig.supxlabel('Age'); #Para etiquetar todo el eje x en los 3plots

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
en medida que hayan menos bins hay muchas mas frecuencias por la acumulacion de las frcuencias
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(x=numerical["Age"]);

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
gen = categorical.Gender.value_counts()

# %%
gen
# Out:
# male      843
# female    466
# Name: Gender, dtype: int64

# %%
plt.pie(gen, labels=gen.index, autopct='%1.1f%%' );

# %%
sns.countplot(x=categorical["Gender"]);

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x=numerical["Pclass"]);

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
numerical.Age.describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
sns.boxplot(data=numerical.Age, color = 'b');

# %%
"""
El boxplot es como el describe en pandas
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
El minimo está cercano a 0, indica habian recien nacidos
La media esta casi en los 30 años
La edad maxima era de 80 años
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.histplot(x=titanic.Age,
             bins=60,
             element='step');   


plt.axvline(titanic.Age.mean(),
            c='blue',
            linewidth=3.,
            linestyle='--',
            label='media de edad')

plt.axvline(titanic.Age.median(),
            c='yellow',
            linewidth=3.,
            linestyle='--',
            label='mediana de edad')

plt.axvline(titanic.Age.mode()[0],
            c='black',
            linewidth=3.,
            linestyle='--',
            label='moda de edad')

plt.title('Histograma de edades Titanic')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.legend()
#plt.savefig('histograma.png')
plt.show();

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
entre los 20 y 30 es donde se concentran la mayoria de las edades, tambien hay muchos mas adultos que niños en el barco
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
plt.plot( titanic.Age, titanic.Fare, 'o');

# %%
sns.scatterplot(x=titanic.Age, y=titanic.Fare);

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr=titanic.corr(method='pearson')

# %%
sns.set(style='dark')                           

mascara=np.triu(np.ones_like(corr, dtype=bool))

cmap=sns.diverging_palette(0, 10, as_cmap=True)


sns.heatmap(corr,             
            mask=mascara,    
            cmap=cmap,
            vmax=1,
            vmin=-1,
            center=0,
            square=True,
            linewidth=0.5,
            
            cbar_kws={'shrink': 0.5},
            annot=True
           );

# %% [markdown]
# #### What are the most correlated features?

# %%
"""

"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
titanic.Age.describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
sns.boxplot(x=titanic.Pclass, y=titanic.Age);

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
face = sns.FacetGrid(titanic, col="Gender", height=4)
face.map(plt.hist, "Age")
plt.show();
