# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import pylab as plt
import seaborn as sns
# Your Code Here

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('../data/fitbit2.csv')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
fitbit.columns
# Out:
# Index(['Date', 'Calorie burned', 'Steps', 'Distance', 'Floors',
#        'Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Fairly Active',
#        'Minutes Very Active', 'Activity Calories', 'MinutesOfSleep',
#        'MinutesOfBeingAwake', 'NumberOfAwakings', 'LengthOfRestInMinutes',
#        'Distance_miles', 'Days', 'Days_encoded', 'Work_or_Weekend',
#        'Hours Sleep', 'Sleep efficiency', 'Yesterday_sleep',
#        'Yesterday_sleep_efficiency', 'Months', 'Months_encoded'],
#       dtype='object')

# %%
data = fitbit.groupby('Months_encoded').Steps.mean()
data.plot();

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
data = fitbit.groupby('Work_or_Weekend').Steps.mean()
data.plot.bar();

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
lista = ['Minutes Sedentary', 'Minutes Lightly Active','Minutes Very Active']
for e in lista:
    sns.scatterplot(data=fitbit,x='Steps',y=f'{e}')
    plt.show()

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('../data/titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.describe().T #include='object'
# Out:
#               count        mean         std   min       25%       50%  \
# PassengerId  1309.0  655.000000  378.020061  1.00  328.0000  655.0000
# Survived      891.0    0.383838    0.486592  0.00    0.0000    0.0000
# Pclass       1309.0    2.294882    0.837836  1.00    2.0000    3.0000
# Age          1309.0   29.879186   13.448335  0.17   22.0000   28.5000
# SibSp        1309.0    0.498854    1.041658  0.00    0.0000    0.0000
# Parch        1309.0    0.385027    0.865560  0.00    0.0000    0.0000
# Fare         1309.0   33.281086   51.741500  0.00    7.8958   14.4542
#
#                  75%        max
# PassengerId  982.000  1309.0000
# Survived       1.000     1.0000
# Pclass         3.000     3.0000
# Age           37.000    80.0000
# SibSp          1.000     8.0000
# Parch          0.000     9.0000
# Fare          31.275   512.3292

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include = 'number').head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include = 'object').head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.rcParams['figure.figsize']=(12, 6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, ax = plt.subplots(1,3,figsize=(12,6))

for i,cat in enumerate(fitbit.index[:3]):
    sns.histplot(x=titanic.Age,bins=10, ax=ax[0]);
    sns.histplot(x=titanic.Age,bins=10, ax=ax[1]);
    sns.histplot(x=titanic.Age,bins=10, ax=ax[2]);

# %%
sns.histplot(x=titanic.Age,
                     bins=20,          # nº de barras
                     kde=True,         # kde=kernel density estimation (la linea)
                     element='step',
                     fill=False
                    );

# %%
sns.histplot(x=titanic.Age,
                     bins=50,          # nº de barras
                     kde=True,         # kde=kernel density estimation (la linea)
                     element='step',
                     fill=False
                    );

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""A mayor bin mayor 'zoom' en los datos, por lo tanto mayor precision por franja de edad"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(x=titanic.Age,
             bins=40,
             element='step'  # contorno de la barra
            );

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
titanic.groupby('Gender').PassengerId.count().plot.bar();

# %%
# Method 2 - seaborn
sns.histplot(x=titanic.Gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.histplot(x=titanic.Pclass)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
titanic.Age.describe().plot.bar();

# %%
"""
Generaria una segunda grafica omitiendo el count, para poder ver con claridad el resto de variables
"""

# %%
titanic.Age.describe()[1:].plot.bar();

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
El general de como esta esa columna de un solo golpe de vista
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.histplot(x=titanic.Age)
plt.axvline(titanic.Age.mean(), color='r')
plt.axvline(titanic.Age.std(), color='g')
plt.axvline(titanic.Age.min(), color='b')
plt.axvline(titanic.Age.quantile(0.25), color='c')
plt.axvline(titanic.Age.quantile(0.55), color='m')
plt.axvline(titanic.Age.quantile(0.75), color='y')
plt.axvline(titanic.Age.max(), color='k')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Toda la info en un mismo grafico
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(x=titanic["Age"], y=titanic["Fare"]);

# %%
# Method 2 - seaborn
sns.regplot(x=titanic["Age"], y=titanic["Fare"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr=titanic.corr(method='pearson')
corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %% [markdown]
# #### What are the most correlated features?

# %%
sns.set(style='white')                            # estilo blanco

mascara=np.triu(np.ones_like(corr, dtype=bool))   # genera una mascara

cmap=sns.diverging_palette(0, 10, as_cmap=True)   # paleta de colores


sns.heatmap(corr,             # datos
            mask=mascara,     # mascara
            cmap=cmap,        # color
            vmax=1,           # maximo vertical
            vmin=-1,          # minimo vertical
            center=0,         # centro
            square=True,      # cuadrado el dato pintado
            linewidth=0.5,    # ancho de la linea
            
            cbar_kws={'shrink': 0.5},  # barra de color
            annot=True                 # anotacion, el numero escrito
           );

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.histplot(x=titanic.Age, 
             hue=titanic.Pclass,
             bins=40,
            );

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sea= sns.FacetGrid(titanic, col="Gender", size=5, aspect=1)
sea.map(plt.hist, 'Age', alpha=.8, bins=20);
# Out:
# C:\Users\Alvaro\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
