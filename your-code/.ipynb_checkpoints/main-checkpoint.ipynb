# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Your Code Here

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('../data/Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fig, ax = plt.subplots(figsize=(12, 4))

ax.plot(fitbit["Months_encoded"]);

# %%
# AVERAGE STEPS BY MONTH_ENCODED
# your code here

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
plt.scatter(fitbit["Minutes Lightly Active"], fitbit["Steps"] , color='red')
plt.title("Minutes Lightly Active vs Steps")
plt.xlabel("Minutes Lightly Active")
plt.ylabel("Steps")
plt.show()

# %%
plt.scatter(fitbit["Minutes Very Active"], fitbit["Steps"] , color='blue')
plt.title("Minutes Very Active vs Steps")
plt.xlabel("Minutes Very Active")
plt.ylabel("Steps")
plt.show()

# %%
plt.scatter(fitbit["Minutes Sedentary"], fitbit["Steps"] , color='green')
plt.title("Minutes Sedentary vs Steps")
plt.xlabel("Minutes Sedentary")
plt.ylabel("Steps")
plt.show()

# %%
# your code here

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('../data/titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
categoricas = titanic.select_dtypes(object)
categoricas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      1309 non-null   object
#  1   Gender    1309 non-null   object
#  2   Ticket    1309 non-null   object
#  3   Cabin     1309 non-null   object
#  4   Embarked  1309 non-null   object
# dtypes: object(5)
# memory usage: 51.3+ KB

# %%
numericas = titanic.select_dtypes(float)
numericas2 = titanic.select_dtypes(int)
numericas = numericas + numericas2
numericas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          0 non-null      float64
#  1   Fare         0 non-null      float64
#  2   Parch        0 non-null      float64
#  3   PassengerId  0 non-null      float64
#  4   Pclass       0 non-null      float64
#  5   SibSp        0 non-null      float64
#  6   Survived     0 non-null      float64
# dtypes: float64(7)
# memory usage: 71.7 KB

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
fig, ax = plt.subplots(figsize=(12,6))
plt.show()

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic["Age"].plot(kind = "hist", bins = 20);

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
titanic["Age"].plot(kind = "hist", bins = 10);

# %%
titanic["Age"].plot(kind = "hist", bins = 20);

# %%
titanic["Age"].plot(kind = "hist", bins = 50);

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
tienes una vision mas concreta de los picos determinados de edad que no seria posible de saber co
con un bin pequeño
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.set_style("whitegrid")

# %%
sns.histplot(data=titanic, x="Age");

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
generos = titanic["Gender"].value_counts()

# %%
plt.bar(generos.index, generos.values)
# Out:
# <BarContainer object of 2 artists>

# %%
sns.countplot(data=titanic, x="Gender")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(data=titanic, x="Pclass")
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
titanic["Age"].plot(kind = "hist", bins = (len(titanic["Age"].unique())))
plt.axvline(titanic.Age.mean(), color='r')
plt.axvline(titanic.Age.std(), color='g')
plt.axvline(titanic.Age.min(), color='b')
plt.axvline(titanic.Age.quantile(0.25), color='c')
plt.axvline(titanic.Age.quantile(0.55), color='m')
plt.axvline(titanic.Age.quantile(0.75), color='y')
plt.axvline(titanic.Age.max(), color='k');

# %%
"""
Aquí estrian todos los valores de edad en un grafico de barras
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
que la mayoria de pasajeros se concentra entre los 16 y los 50 años. 
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
titanic["Age"].plot(kind = "hist", bins = (len(titanic["Age"].unique())), orientation = "horizontal");

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
supongo que seria que hay grupos de edad que tienen valores muy concretos de unas pocas muestras
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(x=titanic['Age'], y=titanic['Fare']);

# %%
# Method 2 - seaborn
sns.set_style("whitegrid")
sns.regplot(data=titanic, x="Age", y="Fare")
plt.xlabel('Edad')
plt.ylabel('Tarifa')
plt.show();

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr=titanic.corr(method='pearson')
sns.set(style='white')                            # estilo blanco

mascara=np.triu(np.ones_like(corr, dtype=bool))   # genera una mascara

cmap=sns.diverging_palette(0, 10, as_cmap=True) 
sns.heatmap(corr,             # datos
            mask=mascara,     # mascara
            cmap=cmap,        # color
            vmax=1,           # maximo vertical
            vmin=-1,          # minimo vertical
            center=0,         # centro
            square=True,      # cuadrado el dato pintado
            linewidth=0.5,    # ancho de la linea
            
            cbar_kws={'shrink': 0.5},  # barra de color
            annot=True                 # anotacion, el numero escrito
           );

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
hay una correlacion entre precio de clase y Fare, tambien entre Age y Pclass
tambien es importante ver que hay una correlacion entre los supervivientes y el precio de la clase

"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(x='Pclass', y='Age', data=titanic);

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.boxplot(x='Gender', y='Age', data=titanic);
